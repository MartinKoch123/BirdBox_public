# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys
sys.path.append("..\..")
from birdbox.database import Image, Url, SearchTerm, SearchHit, Bird, Search, database, backup, peak, show, Crop
from PIL import Image as PIL_Image
import peewee
import matplotlib.pyplot as plt

# %%
backup()

# %%
query = (Image
         .select(Image)
         .join(Url)
         .join(SearchHit)
         .join(SearchTerm)
         .where(SearchTerm.source == "1")
        )

for image_entry in query.limit(100).offset(200):
    plt.imshow(PIL_Image.open(image_entry.file()))
    plt.title(str(image_entry.id))
    plt.show()

# %%
Bird.peak()
# Out:
# id=1, name=Great tit
# id=2, name=Greylag goose
# id=3, name=European robin
# id=4, name=Eurasian blue tit
# id=5, name=Common chaffinch
# id=6, name=European goldfinch
# id=7, name=Eurasian bullfinch

# %%
Url.delete().where(Url.url == "").execute()
# Out:
# 1

# %%
entry = Crop.select().join(Image).where(Image.bird.is_null())

Crop.delete().where(Crop.id == entry[0].id).execute()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-8f3425ed14d4> in <module>
#       1 entry = Crop.select().join(Image).where(Image.bird.is_null())
#       2
# ----> 3 Crop.delete().where(Crop.id == entry[0].id).execute()
#       4
#       5
#
# ~\Anaconda3\lib\site-packages\peewee.py in __getitem__(self, value)
#    1982             index = index + 1 if index >= 0 else 0
#    1983         self._cursor_wrapper.fill_cache(index)
# -> 1984         return self._cursor_wrapper.row_cache[value]
#    1985
#    1986     def __len__(self):
#
# IndexError: list index out of range
